# %%
# Import required libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from xgboost import XGBClassifier
from sklearn.metrics import make_scorer
from sklearn import svm

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report,confusion_matrix
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree # Import Decision Tree Classifier 
from sklearn.metrics import recall_score,precision_score,roc_auc_score,f1_score
from sklearn.ensemble import RandomForestClassifier

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report,confusion_matrix
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_validate
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from sklearn.metrics import matthews_corrcoef
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import ClusterCentroids
from collections import Counter
from imblearn.combine import SMOTEENN
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE, ADASYN
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from mlxtend.classifier import MultiLayerPerceptron as MLP
from sklearn.utils import shuffle
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SMOTENC
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import ShuffleSplit

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Final_Data_Bal.csv')
#df = shuffle(df)
df
# Out:
#        class      mean       std           var  kurtosis      skewness  \
# 0          0  0.043487  0.006204  3.900000e-05  1.000000  1.000000e+00
# 1          0  0.033790  0.000138  3.030000e-08  1.000000  3.850000e-14
# 2          0  0.043825  0.000352  1.520000e-07  0.516043  8.555579e-01
# 3          0  0.045187  0.004859  2.400000e-05  1.000000  1.000000e+00
# 4          0  0.041577  0.000421  2.110000e-07  0.004039  4.682217e-01
# ...      ...       ...       ...           ...       ...           ...
# 17303      0  0.022554  0.041456  1.721820e-03  0.326457  7.818701e-01
# 17304      0  0.029772  0.000415  2.060000e-07  0.100032  6.581390e-01
# 17305      0  0.106924  0.129103  1.667677e-02  0.026604  5.547555e-01
# 17306      0  0.275358  0.176049  3.100492e-02  0.037445  5.265634e-01
# 17307      0  0.045187  0.000880  8.450000e-07  0.752547  9.217969e-01
#
#        quantile1  quantile2  quantile3  quantile4  ...  fquantile5  \
# ...

# %%
print(df.shape)
print(df["class"].value_counts())
df.describe().transpose()
# Out:
# (17308, 39)
# 1    8654
# 0    8654
# Name: class, dtype: int64
#                 count      mean       std           min           25%  \
# class         17308.0  0.500000  0.500014  0.000000e+00  0.000000e+00
# mean          17308.0  0.066154  0.059762  6.670000e-05  3.196292e-02
# std           17308.0  0.061250  0.071924  6.260000e-06  6.493650e-04
# var           17308.0  0.008929  0.021993  5.460000e-10  4.740000e-07
# kurtosis      17308.0  0.367331  0.352854  6.940000e-18  7.702583e-02
# skewness      17308.0  0.710562  0.201489  1.670000e-16  5.886411e-01
# quantile1     17308.0  0.118921  0.056858  1.413465e-03  7.922012e-02
# quantile2     17308.0  0.058165  0.030677  1.110273e-03  3.822408e-02
# quantile3     17308.0  0.060475  0.045914  3.105651e-03  3.422390e-02
# quantile4     17308.0  0.051549  0.056348  9.790000e-05  2.037355e-02
# quantile5     17308.0  0.079257  0.088271  1.680000e-05  1.989097e-02
# ...

# %%
target_column = df['class']
predictors = df.drop(labels=['class'], axis=1)
#predictors =  ['mean', 'var', 'kurtosis', 'skewness', 'quantile1', 'quantile3', 'fmean', 'fstd', 'fskewness', 'fcofvar']
#predictors = ['mean', 'kurtosis', 'skewness', 'quantile1', 'quantile3', 'fmean', 'fcofvar']
#predictors =['quantile1']
#predictors = ['mean', 'quantile1', 'fmean']

# %%
predictors.columns
# Out:
# Index(['mean', 'std', 'var', 'kurtosis', 'skewness', 'quantile1', 'quantile2',
#        'quantile3', 'quantile4', 'quantile5', 'quantile6', 'trimed_Mean',
#        'cofvar', 'invcofvar', 'minimum', 'maxmimum', 'median', 'absenergy',
#        'IQR', 'fmean', 'fstd', 'fvar', 'fkurtosis', 'fskewness', 'fquantile1',
#        'fquantile2', 'fquantile3', 'fquantile4', 'fquantile5', 'fquantile6',
#        'ftrimed_Mean', 'fcofvar', 'finvcofvar', 'fminimum', 'fmaxmimum',
#        'fmedian', 'fabsenergy', 'fIQR'],
#       dtype='object')

# %%
X = predictors.values
#X = df[predictors].values
y = target_column.values

# %% [raw]
# X = MinMaxScaler().fit_transform(X)

# %% [raw]
# rus = RandomOverSampler(random_state=0)
# X_resampled, y_resampled = rus.fit_resample(X, y)
# print(sorted(Counter(y_resampled).items()))
# X = X_resampled
# y = y_resampled

# %% [raw]
# rus = SMOTEENN(random_state=None)
# X_resampled, y_resampled = rus.fit_resample(X, y)
# print(sorted(Counter(y_resampled).items()))
# X = X_resampled
# y = y_resampled

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=1)
print(X_train.shape)
print(X_test.shape)
# Out:
# (15577, 38)
# (1731, 38)

# %% [raw]
# def savebal(X,y):
#  df1 = pd.DataFrame(data=X)
#  df2 = pd.DataFrame(data=y)
#  df1.columns = [predictors]
#  df2.columns = ['class']
#  df3 = pd.concat([df2,df1], axis=1)
#  print(df3["class"].value_counts())
#  df3.to_csv (r'Final_Data_Bal_10.csv', index = False, header=True)
#  print("FINAL BALANCED CSV SAVED...!")

# %% [raw]
# savebal(X,y)

# %%
#IMPORTING MODELS
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network.multilayer_perceptron import MLPClassifier
from sklearn.naive_bayes import MultinomialNB  
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble.weight_boosting import AdaBoostClassifier
from sklearn.ensemble.gradient_boosting import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
#IMPORTING SCORING PARAMETERS
from sklearn.metrics import recall_score,precision_score,roc_auc_score,f1_score,accuracy_score
#PREDICATION START
clf = {'RandomForestClassifier':RandomForestClassifier(),'XGBClassifier':XGBClassifier(),'KNeighborsClassifier':KNeighborsClassifier(),'SVM':svm.SVC(),"DecisionTreeClassifier":DecisionTreeClassifier(),"MLPClassifier":MLPClassifier(),"MultinomialNB":MultinomialNB(),"LogisticRegression":LogisticRegression(),"AdaBoostClassifier":AdaBoostClassifier(),"GradientBoostingClassifier":GradientBoostingClassifier()}
dic =  {"model":[],"Acuracy":[],"Sensitivity":[],"specificity":[],"ROC_AUC":[],"Precision":[],"F-Score":[]}
for name, model in clf.items():
    model.fit(X_train, y_train.ravel())
    #predict_train = model.predict(X_train)
    predict_test = model.predict(X_test)
    Accuracy = accuracy_score(y_test,predict_test)
    Sensitivity = metrics.recall_score(y_test,predict_test)
    ROC_AUC = metrics.roc_auc_score(y_test,predict_test, average="macro")
    Precision =  metrics.precision_score(y_test,predict_test)
    FScore =  metrics.f1_score(y_test,predict_test)
    print("--------------------------------------------------------------")
    print("Model:", name)
    print("Accuracy:", accuracy_score(y_test,predict_test))
    print("Sensitivity/Recall:",metrics.recall_score(y_test,predict_test))
    tn, fp, fn, tp = confusion_matrix(y_test,predict_test).ravel()
    specificity = tn / (tn+fp)
    print("Specificity:", specificity)
    print("ROC_AUC scores:",metrics.roc_auc_score(y_test,predict_test, average="macro"))
    print("Precision:", metrics.precision_score(y_test,predict_test))
    print("F-Score:", metrics.f1_score(y_test,predict_test))
    dic["model"].append(name)
    dic["Acuracy"].append(Accuracy)
    dic["Sensitivity"].append(Sensitivity)
    dic["specificity"].append(specificity)
    dic["ROC_AUC"].append(ROC_AUC)
    dic["Precision"].append(Precision)
    dic["F-Score"].append(FScore)
final_data = pd.DataFrame(dic)
print("==================================================================")
print("Best Model")
print("==================================================================")
print(final_data.max())
print("==================================================================")
final_data
# Out:
# --------------------------------------------------------------
# Model: RandomForestClassifier
# Accuracy: 0.9872905834777586
# Sensitivity/Recall: 0.9943117178612059
# Specificity: 0.9800469483568075
# ROC_AUC scores: 0.9871793331090066
# Precision: 0.9809203142536476
# F-Score: 0.9875706214689265
# --------------------------------------------------------------
# Model: XGBClassifier
# Accuracy: 0.9948006932409013
# Sensitivity/Recall: 0.9988623435722411
# Specificity: 0.9906103286384976
# ROC_AUC scores: 0.9947363361053695
# Precision: 0.9909706546275395
# F-Score: 0.994900849858357
# --------------------------------------------------------------
# Model: KNeighborsClassifier
# Accuracy: 0.9688041594454073
# Sensitivity/Recall: 0.9806598407281001
# Specificity: 0.9565727699530516
# ROC_AUC scores: 0.968616305340576
# Precision: 0.9588431590656284
# F-Score: 0.9696287964004499
# --------------------------------------------------------------
# Model: SVM
# ...

# %%
#model = RandomForestClassifier(max_features=0.90000001, min_samples_leaf=10, min_samples_split=10, n_estimators=1000)
model = XGBClassifier(n_estimators=1000,early_stopping_rounds = 10)
#model = KNeighborsClassifier()
#model = svm.SVC(kernel='rbf')

# %%
# %%time
#scoring = {'accuracy','recall', 'precision','f1','roc_auc','specificity': make_scorer(recall_score,pos_label=0)}
scoring = {
    'accuracy': make_scorer(accuracy_score),
    'sensitivity/recall': make_scorer(recall_score),
    'specificity': make_scorer(recall_score,pos_label=0),
    'precision': make_scorer(precision_score),
    'f1':make_scorer(f1_score),
    'roc_auc':make_scorer(roc_auc_score),
    'Mcc':make_scorer(matthews_corrcoef)
}
cv_results = cross_validate(model, X, y.ravel(), cv=10, scoring=scoring)
cr = pd.DataFrame(cv_results)
testre = cr.drop(['fit_time', 'score_time'], axis=1)
print(testre.mean(axis = 0))
vis = testre.drop(['test_precision', 'test_f1','test_Mcc','test_roc_auc'], axis=1)
vis.plot()
plt.title('10-Fold Cross Validation Graph ', fontsize = 14)
plt.xlabel('Scoring (0-1)')
plt.ylabel('10-Fold')
cr
# Out:
# test_accuracy              0.994801
# test_sensitivity/recall    0.998382
# test_specificity           0.991218
# test_precision             0.991311
# test_f1                    0.994825
# test_roc_auc               0.994800
# test_Mcc                   0.989644
# dtype: float64
# Wall time: 2min 10s
#     fit_time  score_time  test_accuracy  test_sensitivity/recall  \
# 0  11.965158    0.024675       0.995956                 1.000000
# 1  11.358428    0.031243       0.990179                 0.994220
# 2  12.425792    0.049872       0.994223                 0.993064
# 3  15.185599    0.047554       0.994801                 0.996532
# 4  14.055706    0.031242       0.993068                 1.000000
# 5  12.974314    0.028569       0.997111                 1.000000
# 6  13.021593    0.037849       0.993068                 1.000000
# 7  12.544405    0.028923       0.991334                 1.000000
# 8  12.991143    0.031243       0.998266                 1.000000
# ...

# %%
# %%time
model.fit(X_train, y_train.ravel())

predict_train = model.predict(X_train)
predict_test = model.predict(X_test)
# Out:
# Wall time: 13.7 s

# %%
print("Confustion Matrix For Training Data")
print("-------------------------------------")
print(confusion_matrix(y_train,predict_train))
print("-------------------------------------")
print("Accuracy:", accuracy_score(y_train,predict_train))
print("Sensitivity/Recall:",metrics.recall_score(y_train,predict_train))
tn, fp, fn, tp = confusion_matrix(y_train,predict_train).ravel()
specificity = tn / (tn+fp)
print("Specificity:", specificity)
print("Precision:", metrics.precision_score(y_train,predict_train))
print("F-Score:", metrics.f1_score(y_train,predict_train))
print("Mens Squre Error:", mean_squared_error(y_test,predict_test))
print("Root Mens Squre Error:", np.sqrt(mean_squared_error(y_test,predict_test)))
print("ROC_AUC scores:",metrics.roc_auc_score(y_train,predict_train, average="macro"))

# Compute fpr, tpr, thresholds and roc auc
fpr, tpr, thresholds = roc_curve(y_train,predict_train)
roc_auc = auc(fpr,tpr)

# Plot ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate or (1 - Specifity)')
plt.ylabel('True Positive Rate or (Sensitivity)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
# Out:
# Confustion Matrix For Training Data
# -------------------------------------
# [[7802    0]
#  [   0 7775]]
# -------------------------------------
# Accuracy: 1.0
# Sensitivity/Recall: 1.0
# Specificity: 1.0
# Precision: 1.0
# F-Score: 1.0
# Mens Squre Error: 0.00462160600808781
# Root Mens Squre Error: 0.06798239483930976
# ROC_AUC scores: 1.0

# %%
print("Confustion Matrix For Testing Data")
print("-------------------------------------")
print(confusion_matrix(y_test,predict_test))
print("-------------------------------------")
print("Accuracy:", accuracy_score(y_test,predict_test))
print("Sensitivity/Recall:",metrics.recall_score(y_test,predict_test))
tn, fp, fn, tp = confusion_matrix(y_test,predict_test).ravel()
specificity = tn / (tn+fp)
print("Specificity:", specificity)
print("Precision:", metrics.precision_score(y_test,predict_test))
print("F-Score:", metrics.f1_score(y_test,predict_test))
print("Mens Squre Error:", mean_squared_error(y_test,predict_test))
print("Root Mens Squre Error:", np.sqrt(mean_squared_error(y_test,predict_test)))
print("ROC_AUC scores:",metrics.roc_auc_score(y_test,predict_test, average="macro"))

# Compute fpr, tpr, thresholds and roc auc
fpr, tpr, thresholds = roc_curve(y_test,predict_test)
roc_auc = auc(fpr,tpr)

# Plot ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate or (1 - Specifity)')
plt.ylabel('True Positive Rate or (Sensitivity)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
# Out:
# Confustion Matrix For Testing Data
# -------------------------------------
# [[845   7]
#  [  1 878]]
# -------------------------------------
# Accuracy: 0.9953783939919122
# Sensitivity/Recall: 0.9988623435722411
# Specificity: 0.9917840375586855
# Precision: 0.992090395480226
# F-Score: 0.9954648526077097
# Mens Squre Error: 0.00462160600808781
# Root Mens Squre Error: 0.06798239483930976
# ROC_AUC scores: 0.9953231905654634

# %%
from pycm import *
cm = ConfusionMatrix(actual_vector=y_test, predict_vector=predict_test)
print(cm)
# Out:
# Predict   0         1
# Actual
# 0         845       7
#
# 1         1         878
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.99218,0.99857)
# ACC Macro                                                         0.99538
# AUNP                                                              0.99532
# AUNU                                                              0.99532
# Bennett S                                                         0.99076
# CBA                                                               0.99194
# CSI                                                               0.99078
# Chi-Squared                                                       1699.21846
# Chi-Squared DF                                                    1
# Conditional Entropy                                               0.04031
# Cramer V                                                          0.99078
# ...

# %%
from sklearn.model_selection import train_test_split
import xgboost
import numpy as np
import matplotlib.pylab as plt

# %%
fig, ax = plt.subplots(figsize=(12,18))
model.get_booster().feature_names = ['mean', 'std', 'var', 'kurtosis', 'skewness', 'quantile1', 'quantile2',
       'quantile3', 'quantile4', 'quantile5', 'quantile6', 'trimed_Mean',
       'cofvar', 'invcofvar', 'minimum', 'maxmimum', 'median', 'absenergy',
       'IQR', 'fmean', 'fstd', 'fvar', 'fkurtosis', 'fskewness', 'fquantile1',
       'fquantile2', 'fquantile3', 'fquantile4', 'fquantile5', 'fquantile6',
       'ftrimed_Mean', 'fcofvar', 'finvcofvar', 'fminimum', 'fmaxmimum',
       'fmedian', 'fabsenergy', 'fIQR']
xgboost.plot_importance(model,height=0.5, ax=ax)
plt.figsize=(30, 10)
plt.title("xgboost.plot_importance(model)")
plt.show()
