# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from imblearn.over_sampling import RandomOverSampler
from imblearn.combine import SMOTEENN
from collections import Counter
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("Final_Data_Raw.csv")

# %%
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26235 entries, 0 to 26234
# Data columns (total 41 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            26235 non-null  object
#  1   class         26235 non-null  int64
#  2   class_str     26235 non-null  object
#  3   mean          26230 non-null  float64
#  4   std           26229 non-null  float64
#  5   var           26229 non-null  float64
#  6   kurtosis      26227 non-null  float64
#  7   skewness      26228 non-null  float64
#  8   quantile1     26230 non-null  float64
#  9   quantile2     26230 non-null  float64
#  10  quantile3     26230 non-null  float64
#  11  quantile4     26230 non-null  float64
#  12  quantile5     26230 non-null  float64
#  13  quantile6     26230 non-null  float64
#  14  trimed_Mean   26230 non-null  float64
#  15  cofvar        26229 non-null  float64
#  16  invcofvar     26229 non-null  float64
# ...

# %%
df["class"].value_counts()
# Out:
# 0    17021
# 1     9214
# Name: class, dtype: int64

# %%
len(df.columns)
# Out:
# 41

# %% [raw]
# df = df.round(3)

# %%
df.iloc[298:312 : ]
# Out:
#               Id  class class_str      mean       std       var   kurtosis  \
# 298  condition_1      1        c1 -0.498829  0.000000  0.000000   0.000000
# 299  condition_1      1        c1 -0.498829  0.000000  0.000000   0.000000
# 300  condition_1      1        c1 -0.498829  0.000000  0.000000   0.000000
# 301  condition_1      1        c1 -0.498829  0.000000  0.000000   0.000000
# 302  condition_1      1        c1 -0.498829  0.000000  0.000000   0.000000
# 303  condition_1      1        c1 -0.498829  0.000000  0.000000   0.000000
# 304  condition_1      1        c1 -0.498829  0.000000  0.000000   0.000000
# 305  condition_1      1        c1 -0.498829  0.000000  0.000000   0.000000
# 306  condition_1      1        c1 -0.498829  0.000000  0.000000   0.000000
# 307  condition_1      1        c1 -0.498376  0.002536  0.000006  34.691234
# 308  condition_1      1        c1 -0.498376  0.002536  0.000006  34.691234
# ...

# %%
df = df.replace([np.inf, -np.inf], 0)

# %%
df = df.dropna()

# %%
df["class"].value_counts()
# Out:
# 0    17015
# 1     9212
# Name: class, dtype: int64

# %%
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26227 entries, 0 to 26234
# Data columns (total 41 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            26227 non-null  object
#  1   class         26227 non-null  int64
#  2   class_str     26227 non-null  object
#  3   mean          26227 non-null  float64
#  4   std           26227 non-null  float64
#  5   var           26227 non-null  float64
#  6   kurtosis      26227 non-null  float64
#  7   skewness      26227 non-null  float64
#  8   quantile1     26227 non-null  float64
#  9   quantile2     26227 non-null  float64
#  10  quantile3     26227 non-null  float64
#  11  quantile4     26227 non-null  float64
#  12  quantile5     26227 non-null  float64
#  13  quantile6     26227 non-null  float64
#  14  trimed_Mean   26227 non-null  float64
#  15  cofvar        26227 non-null  float64
#  16  invcofvar     26227 non-null  float64
# ...

# %%
df = df.drop(['Id','class_str'], axis=1)

# %%
df
# Out:
#        class      mean       std       var   kurtosis  skewness  quantile1  \
# 0          1  0.677568  0.882348  0.778538   1.112264  1.046916  -0.498829
# 1          1  0.467159  0.793051  0.628930   0.466533  0.965757  -0.498829
# 2          1  0.448885  0.924378  0.854475   1.249442  1.231372  -0.498829
# 3          1  0.243852  1.012819  1.025803   8.933094  2.672737  -0.498829
# 4          1  0.310951  0.913359  0.834225   3.080803  1.665956  -0.498829
# ...      ...       ...       ...       ...        ...       ...        ...
# 26230      0 -0.194495  0.800346  0.640554  17.928978  4.056770  -0.426260
# 26231      0  0.114147  1.010018  1.020136   6.488370  2.574614  -0.417758
# 26232      0 -0.231127  0.462815  0.214198   5.568872  2.564643  -0.434763
# 26233      0 -0.434763  0.000000  0.000000   0.000000  0.000000  -0.434763
# 26234      0 -0.420836  0.056835  0.003230  48.300367  6.780410  -0.434763
#
# ...

# %%
df.to_csv (r'Final_Data_Pre.csv', index = False, header=True)

# %%
df["class"].value_counts()
# Out:
# 0    17015
# 1     9212
# Name: class, dtype: int64

# %%
df.columns
# Out:
# Index(['class', 'mean', 'std', 'var', 'kurtosis', 'skewness', 'quantile1',
#        'quantile2', 'quantile3', 'quantile4', 'quantile5', 'quantile6',
#        'trimed_Mean', 'cofvar', 'invcofvar', 'minimum', 'maxmimum', 'median',
#        'absenergy', 'IQR', 'fmean', 'fstd', 'fvar', 'fkurtosis', 'fskewness',
#        'fquantile1', 'fquantile2', 'fquantile3', 'fquantile4', 'fquantile5',
#        'fquantile6', 'ftrimed_Mean', 'fcofvar', 'finvcofvar', 'fminimum',
#        'fmaxmimum', 'fmedian', 'fabsenergy', 'fIQR'],
#       dtype='object')

# %%
columns = ['mean', 'std', 'var', 'kurtosis', 'skewness', 'quantile1',
       'quantile2', 'quantile3', 'quantile4', 'quantile5', 'quantile6',
       'trimed_Mean', 'cofvar', 'invcofvar', 'minimum', 'maxmimum', 'median',
       'absenergy', 'IQR', 'fmean', 'fstd', 'fvar', 'fkurtosis', 'fskewness',
       'fquantile1', 'fquantile2', 'fquantile3', 'fquantile4', 'fquantile5',
       'fquantile6', 'ftrimed_Mean', 'fcofvar', 'finvcofvar', 'fminimum',
       'fmaxmimum', 'fmedian', 'fabsenergy', 'fIQR']

# %% [raw]
# li = df["class"].astype(int)

# %%
df[columns] = df[columns].replace(to_replace=0, method='ffill')

# %% [raw]
# df["class"] = df["class"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26227 entries, 0 to 26234
# Data columns (total 39 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   class         26227 non-null  int64
#  1   mean          26227 non-null  float64
#  2   std           26227 non-null  float64
#  3   var           26227 non-null  float64
#  4   kurtosis      26227 non-null  float64
#  5   skewness      26227 non-null  float64
#  6   quantile1     26227 non-null  float64
#  7   quantile2     26227 non-null  float64
#  8   quantile3     26227 non-null  float64
#  9   quantile4     26227 non-null  float64
#  10  quantile5     26227 non-null  float64
#  11  quantile6     26227 non-null  float64
#  12  trimed_Mean   26227 non-null  float64
#  13  cofvar        26227 non-null  float64
#  14  invcofvar     26227 non-null  float64
#  15  minimum       26227 non-null  float64
#  16  maxmimum      26227 non-null  float64
# ...

# %%
df
# Out:
#        class      mean       std       var   kurtosis  skewness  quantile1  \
# 0          1  0.677568  0.882348  0.778538   1.112264  1.046916  -0.498829
# 1          1  0.467159  0.793051  0.628930   0.466533  0.965757  -0.498829
# 2          1  0.448885  0.924378  0.854475   1.249442  1.231372  -0.498829
# 3          1  0.243852  1.012819  1.025803   8.933094  2.672737  -0.498829
# 4          1  0.310951  0.913359  0.834225   3.080803  1.665956  -0.498829
# ...      ...       ...       ...       ...        ...       ...        ...
# 26230      0 -0.194495  0.800346  0.640554  17.928978  4.056770  -0.426260
# 26231      0  0.114147  1.010018  1.020136   6.488370  2.574614  -0.417758
# 26232      0 -0.231127  0.462815  0.214198   5.568872  2.564643  -0.434763
# 26233      0 -0.434763  0.462815  0.214198   5.568872  2.564643  -0.434763
# 26234      0 -0.420836  0.056835  0.003230  48.300367  6.780410  -0.434763
#
# ...

# %%
df.to_csv (r'Final_Data_Pre_NonZero.csv', index = False, header=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26227 entries, 0 to 26234
# Data columns (total 39 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   class         26227 non-null  int64
#  1   mean          26227 non-null  float64
#  2   std           26227 non-null  float64
#  3   var           26227 non-null  float64
#  4   kurtosis      26227 non-null  float64
#  5   skewness      26227 non-null  float64
#  6   quantile1     26227 non-null  float64
#  7   quantile2     26227 non-null  float64
#  8   quantile3     26227 non-null  float64
#  9   quantile4     26227 non-null  float64
#  10  quantile5     26227 non-null  float64
#  11  quantile6     26227 non-null  float64
#  12  trimed_Mean   26227 non-null  float64
#  13  cofvar        26227 non-null  float64
#  14  invcofvar     26227 non-null  float64
#  15  minimum       26227 non-null  float64
#  16  maxmimum      26227 non-null  float64
# ...

# %% [raw]
# df = df.reset_index()

# %% [raw]
# df = df.drop(['index'], axis=1)

# %%
#df.to_csv (r'Final_Data_Suff_Nom.csv', index = False, header=True)

# %%
df = shuffle(df)
df
# Out:
#        class      mean       std       var   kurtosis  skewness  quantile1  \
# 4824       1 -0.263247  0.616983  0.380668  26.092675  4.735134  -0.452436
# 8878       1  0.343830  1.088487  1.184803   3.843981  1.822663  -0.580284
# 3537       1  0.278625  0.904398  0.817935   1.208436  1.316541  -0.485234
# 5271       1  0.515367  1.223625  1.497258   3.445233  1.966008  -0.369124
# 16257      0 -0.622902  0.016699  0.000279  26.124114  5.034397  -0.628746
# ...      ...       ...       ...       ...        ...       ...        ...
# 16076      0  0.474567  1.522594  2.318292   3.425758  1.783431  -0.636664
# 24337      0 -0.378354  0.003366  0.000011  -0.613364  0.104282  -0.382971
# 4718       1 -0.441755  0.029543  0.000873   8.980538  3.044914  -0.455459
# 8944       1 -0.183200  0.691820  0.478614   1.863345  1.753519  -0.580284
# 4182       1 -0.540329  0.050382  0.002538  57.073422  7.490813  -0.547938
#
# ...

# %%
li = df["class"].astype(int)

# %%
df.columns
# Out:
# Index(['class', 'mean', 'std', 'var', 'kurtosis', 'skewness', 'quantile1',
#        'quantile2', 'quantile3', 'quantile4', 'quantile5', 'quantile6',
#        'trimed_Mean', 'cofvar', 'invcofvar', 'minimum', 'maxmimum', 'median',
#        'absenergy', 'IQR', 'fmean', 'fstd', 'fvar', 'fkurtosis', 'fskewness',
#        'fquantile1', 'fquantile2', 'fquantile3', 'fquantile4', 'fquantile5',
#        'fquantile6', 'ftrimed_Mean', 'fcofvar', 'finvcofvar', 'fminimum',
#        'fmaxmimum', 'fmedian', 'fabsenergy', 'fIQR'],
#       dtype='object')

# %%
columns = ['mean', 'std', 'var', 'kurtosis', 'skewness', 'quantile1',
       'quantile2', 'quantile3', 'quantile4', 'quantile5', 'quantile6',
       'trimed_Mean', 'cofvar', 'invcofvar', 'minimum', 'maxmimum', 'median',
       'absenergy', 'IQR', 'fmean', 'fstd', 'fvar', 'fkurtosis', 'fskewness',
       'fquantile1', 'fquantile2', 'fquantile3', 'fquantile4', 'fquantile5',
       'fquantile6', 'ftrimed_Mean', 'fcofvar', 'finvcofvar', 'fminimum',
       'fmaxmimum', 'fmedian', 'fabsenergy', 'fIQR']

# %%
X = MinMaxScaler().fit_transform(df[columns])
df[columns] = X

# %%
df[columns] = df[columns].replace(to_replace=0, method='ffill')

# %%
df
# Out:
#        class      mean       std           var  kurtosis  skewness  quantile1  \
# 4824       1  0.051715  0.086407  7.472515e-03  0.453726  0.805652   0.125621
# 8878       1  0.116606  0.152471  2.325772e-02  0.095282  0.617652   0.071108
# 3537       1  0.109636  0.126677  1.605610e-02  0.052821  0.584982   0.111636
# 5271       1  0.134942  0.171405  2.939122e-02  0.088858  0.626905   0.161144
# 16257      0  0.013270  0.002299  5.472028e-06  0.454232  0.824969   0.050444
# ...      ...       ...       ...           ...       ...       ...        ...
# 16076      0  0.130581  0.213295  4.550815e-02  0.088544  0.615120   0.047068
# 24337      0  0.039411  0.000431  2.207904e-07  0.023470  0.506731   0.155240
# 4718       1  0.032634  0.004099  1.713136e-05  0.178036  0.696548   0.124332
# 8944       1  0.060271  0.096892  9.395212e-03  0.063372  0.613189   0.071108
# 4182       1  0.022097  0.007019  4.982621e-05  0.952850  0.983530   0.084900
#
# ...

# %%
df.to_csv (r'Final_Data_Suff_Nom.csv', index = False, header=True)

# %%
df
# Out:
#        class      mean       std           var  kurtosis  skewness  quantile1  \
# 4824       1  0.051715  0.086407  7.472515e-03  0.453726  0.805652   0.125621
# 8878       1  0.116606  0.152471  2.325772e-02  0.095282  0.617652   0.071108
# 3537       1  0.109636  0.126677  1.605610e-02  0.052821  0.584982   0.111636
# 5271       1  0.134942  0.171405  2.939122e-02  0.088858  0.626905   0.161144
# 16257      0  0.013270  0.002299  5.472028e-06  0.454232  0.824969   0.050444
# ...      ...       ...       ...           ...       ...       ...        ...
# 16076      0  0.130581  0.213295  4.550815e-02  0.088544  0.615120   0.047068
# 24337      0  0.039411  0.000431  2.207904e-07  0.023470  0.506731   0.155240
# 4718       1  0.032634  0.004099  1.713136e-05  0.178036  0.696548   0.124332
# 8944       1  0.060271  0.096892  9.395212e-03  0.063372  0.613189   0.071108
# 4182       1  0.022097  0.007019  4.982621e-05  0.952850  0.983530   0.084900
#
# ...

# %%
target_column = ['class'] 
predictors = list(set(list(df.columns))-set(target_column))

# %%
X = df[predictors].values
y = df[target_column].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-95358ee881d8> in <module>
#       1 X = df[predictors].values
# ----> 2 y = df[target_column].values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1533         # Have the index compute an indexer or return None
#    1534         # if it cannot handle:
# -> 1535         indexer, keyarr = ax._convert_listlike_indexer(key, kind=self.name)
# ...

# %%
rus = SMOTEENN(random_state=0)
X_resampled, y_resampled = rus.fit_resample(X, y)
print(sorted(Counter(y_resampled).items()))
X = X_resampled
y = y_resampled
# Out:
# [(0, 7612), (1, 11000)]

# %%
df1 = pd.DataFrame(data=X)
df2 = pd.DataFrame(data=y)

# %%
df1.columns = [predictors]
df2.columns = ['class']

# %%
df3 = pd.concat([df1,df2], axis=1)

# %%
df3["class"].value_counts()

# %%
#df3.to_csv (r'Final_Data_Bal,csv', index = False, header=True)
