# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle

# %%
df1 = pd.read_csv("final_data_Temp.csv")
df2 = pd.read_csv("final_data_Frq.csv")

# %%
print(df1.info())
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26235 entries, 0 to 26234
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           26235 non-null  object
#  1   class        26235 non-null  int64
#  2   class_str    26235 non-null  object
#  3   mean         26230 non-null  float64
#  4   std          26229 non-null  float64
#  5   var          26229 non-null  float64
#  6   kurtosis     26227 non-null  float64
#  7   skewness     26228 non-null  float64
#  8   quantile1    26230 non-null  float64
#  9   quantile2    26230 non-null  float64
#  10  quantile3    26230 non-null  float64
#  11  quantile4    26230 non-null  float64
#  12  quantile5    26230 non-null  float64
#  13  quantile6    26230 non-null  float64
#  14  trimed_Mean  26230 non-null  float64
#  15  cofvar       26229 non-null  float64
#  16  invcofvar    26229 non-null  float64
#  17  minimum      26230 non-null  float64
# ...

# %%
print(df2.info())
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26235 entries, 0 to 26234
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FId           26235 non-null  object
#  1   Fclass        26235 non-null  int64
#  2   Fclass_str    26235 non-null  object
#  3   fmean         26230 non-null  float64
#  4   fstd          26229 non-null  float64
#  5   fvar          26229 non-null  float64
#  6   fkurtosis     26227 non-null  float64
#  7   fskewness     26228 non-null  float64
#  8   fquantile1    26230 non-null  float64
#  9   fquantile2    26230 non-null  float64
#  10  fquantile3    26230 non-null  float64
#  11  fquantile4    26230 non-null  float64
#  12  fquantile5    26230 non-null  float64
#  13  fquantile6    26230 non-null  float64
#  14  ftrimed_Mean  26230 non-null  float64
#  15  fcofvar       26229 non-null  float64
#  16  finvcofvar    26229 non-null  float64
# ...

# %%
df = pd.concat([df1,df2], axis=1)

# %%
df
# Out:
#                 Id  class class_str      mean       std       var   kurtosis  \
# 0      condition_1      1        c1  0.677568  0.882348  0.778538   1.112264
# 1      condition_1      1        c1  0.467159  0.793051  0.628930   0.466533
# 2      condition_1      1        c1  0.448885  0.924378  0.854475   1.249442
# 3      condition_1      1        c1  0.243852  1.012819  1.025803   8.933094
# 4      condition_1      1        c1  0.310951  0.913359  0.834225   3.080803
# ...            ...    ...       ...       ...       ...       ...        ...
# 26230   control_32      0        c0 -0.194495  0.800346  0.640554  17.928978
# 26231   control_32      0        c0  0.114147  1.010018  1.020136   6.488370
# 26232   control_32      0        c0 -0.231127  0.462815  0.214198   5.568872
# 26233   control_32      0        c0 -0.434763  0.000000  0.000000   0.000000
# 26234   control_32      0        c0 -0.420836  0.056835  0.003230  48.300367
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26235 entries, 0 to 26234
# Data columns (total 44 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            26235 non-null  object
#  1   class         26235 non-null  int64
#  2   class_str     26235 non-null  object
#  3   mean          26230 non-null  float64
#  4   std           26229 non-null  float64
#  5   var           26229 non-null  float64
#  6   kurtosis      26227 non-null  float64
#  7   skewness      26228 non-null  float64
#  8   quantile1     26230 non-null  float64
#  9   quantile2     26230 non-null  float64
#  10  quantile3     26230 non-null  float64
#  11  quantile4     26230 non-null  float64
#  12  quantile5     26230 non-null  float64
#  13  quantile6     26230 non-null  float64
#  14  trimed_Mean   26230 non-null  float64
#  15  cofvar        26229 non-null  float64
#  16  invcofvar     26229 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Id', 'class', 'class_str', 'mean', 'std', 'var', 'kurtosis',
#        'skewness', 'quantile1', 'quantile2', 'quantile3', 'quantile4',
#        'quantile5', 'quantile6', 'trimed_Mean', 'cofvar', 'invcofvar',
#        'minimum', 'maxmimum', 'median', 'absenergy', 'IQR', 'FId', 'Fclass',
#        'Fclass_str', 'fmean', 'fstd', 'fvar', 'fkurtosis', 'fskewness',
#        'fquantile1', 'fquantile2', 'fquantile3', 'fquantile4', 'fquantile5',
#        'fquantile6', 'ftrimed_Mean', 'fcofvar', 'finvcofvar', 'fminimum',
#        'fmaxmimum', 'fmedian', 'fabsenergy', 'fIQR'],
#       dtype='object')

# %%
df = df.drop(['FId','Fclass','Fclass_str'], axis=1)

# %%
df
# Out:
#                 Id  class class_str      mean       std       var   kurtosis  \
# 0      condition_1      1        c1  0.677568  0.882348  0.778538   1.112264
# 1      condition_1      1        c1  0.467159  0.793051  0.628930   0.466533
# 2      condition_1      1        c1  0.448885  0.924378  0.854475   1.249442
# 3      condition_1      1        c1  0.243852  1.012819  1.025803   8.933094
# 4      condition_1      1        c1  0.310951  0.913359  0.834225   3.080803
# ...            ...    ...       ...       ...       ...       ...        ...
# 26230   control_32      0        c0 -0.194495  0.800346  0.640554  17.928978
# 26231   control_32      0        c0  0.114147  1.010018  1.020136   6.488370
# 26232   control_32      0        c0 -0.231127  0.462815  0.214198   5.568872
# 26233   control_32      0        c0 -0.434763  0.000000  0.000000   0.000000
# 26234   control_32      0        c0 -0.420836  0.056835  0.003230  48.300367
#
# ...

# %%
df.columns
# Out:
# Index(['Id', 'class', 'class_str', 'mean', 'std', 'var', 'kurtosis',
#        'skewness', 'quantile1', 'quantile2', 'quantile3', 'quantile4',
#        'quantile5', 'quantile6', 'trimed_Mean', 'cofvar', 'invcofvar',
#        'minimum', 'maxmimum', 'median', 'absenergy', 'IQR', 'fmean', 'fstd',
#        'fvar', 'fkurtosis', 'fskewness', 'fquantile1', 'fquantile2',
#        'fquantile3', 'fquantile4', 'fquantile5', 'fquantile6', 'ftrimed_Mean',
#        'fcofvar', 'finvcofvar', 'fminimum', 'fmaxmimum', 'fmedian',
#        'fabsenergy', 'fIQR'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26235 entries, 0 to 26234
# Data columns (total 41 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            26235 non-null  object
#  1   class         26235 non-null  int64
#  2   class_str     26235 non-null  object
#  3   mean          26230 non-null  float64
#  4   std           26229 non-null  float64
#  5   var           26229 non-null  float64
#  6   kurtosis      26227 non-null  float64
#  7   skewness      26228 non-null  float64
#  8   quantile1     26230 non-null  float64
#  9   quantile2     26230 non-null  float64
#  10  quantile3     26230 non-null  float64
#  11  quantile4     26230 non-null  float64
#  12  quantile5     26230 non-null  float64
#  13  quantile6     26230 non-null  float64
#  14  trimed_Mean   26230 non-null  float64
#  15  cofvar        26229 non-null  float64
#  16  invcofvar     26229 non-null  float64
# ...

# %%
#df = shuffle(df)
df
# Out:
#                 Id  class class_str      mean       std       var   kurtosis  \
# 0      condition_1      1        c1  0.677568  0.882348  0.778538   1.112264
# 1      condition_1      1        c1  0.467159  0.793051  0.628930   0.466533
# 2      condition_1      1        c1  0.448885  0.924378  0.854475   1.249442
# 3      condition_1      1        c1  0.243852  1.012819  1.025803   8.933094
# 4      condition_1      1        c1  0.310951  0.913359  0.834225   3.080803
# ...            ...    ...       ...       ...       ...       ...        ...
# 26230   control_32      0        c0 -0.194495  0.800346  0.640554  17.928978
# 26231   control_32      0        c0  0.114147  1.010018  1.020136   6.488370
# 26232   control_32      0        c0 -0.231127  0.462815  0.214198   5.568872
# 26233   control_32      0        c0 -0.434763  0.000000  0.000000   0.000000
# 26234   control_32      0        c0 -0.420836  0.056835  0.003230  48.300367
#
# ...

# %%
df.to_csv (r'Final_Data_Raw.csv', index = False, header=True)
